# %%
import pandas as pd
import random

# %%
df_test = pd.read_csv('data/test.csv')
df_test = df_test[['id']]
df_test['log_price'] = [random.uniform(0, 8)]*len(df_test)
df_test
#df_test.to_csv('sampleSubmission.csv', index=False)
# Out:
#              id  log_price
# 0        986942   3.100544
# 1      16436737   3.100544
# 2      18209634   3.100544
# 3      15027024   3.100544
# 4      18074243   3.100544
# 5       8446914   3.100544
# 6      19362916   3.100544
# 7      16116059   3.100544
# 8      20912583   3.100544
# 9      13573101   3.100544
# 10     15938749   3.100544
# 11     13659214   3.100544
# 12      6239753   3.100544
# 13     11627400   3.100544
# 14     17794295   3.100544
# 15     15267276   3.100544
# 16      9476370   3.100544
# 17     14694999   3.100544
# 18     19847012   3.100544
# 19      8860277   3.100544
# 20      2975445   3.100544
# 21      1390712   3.100544
# 22     16144412   3.100544
# 23      1312673   3.100544
# 24      6645473   3.100544
# 25      7227023   3.100544
# 26     17283456   3.100544
# 27     13719227   3.100544
# 28     11413078   3.100544
# 29     15166399   3.100544
# ...         ...        ...
# 23081    840797   3.100544
# 23082   4880277   3.100544
# ...
